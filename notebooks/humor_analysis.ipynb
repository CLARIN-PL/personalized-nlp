# %%
# %load_ext autoreload
# %autoreload 2

import sys
sys.path.append('../../')

import os
os.environ["CUDA_VISIBLE_DEVICES"] = '1'
os.environ["WANDB_START_METHOD"] = "thread"
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import torch
import numpy as np
import random

def seed_everything():
    torch.manual_seed(0)
    random.seed(0)
    np.random.seed(0)

# %% [markdown]
# ## Load dataset

# %%
from personalized_nlp.datasets.humor.humor import HumorDataModule

# %%
humor_module = HumorDataModule(normalize=True)
humor_module.prepare_data()

humor_module.setup()

# %%
TEST_FOLD = 0 
test_text_ids = []
for batch in humor_module.test_dataloader(test_fold=TEST_FOLD):
    test_text_ids.extend(batch[0]['text_ids'].tolist())
humor_module.data.iloc[test_text_ids]
# Out:
#                   text_id                                               text  \
# 17      16235575870758912  Mamá ¿por qué yo soy negro, tu amarilla y papá...
# 21      16599228113494016  Si tu ex te dice: ¡Nunca encontrarás a alguien...
# 58      21304298788888576  Si estás tirando y tu pareja te pide hacer el ...
# 112     24242659388293120  -A esa le dicen la Maruchan -¿Por qué? -Porque...
# 125     24898356400623616  ¿Será verdad que los vegetarianos no pueden te...
# ...                   ...                                                ...
# 14866  496676658204921857        ¿Te desmayaste? No, me estoy reiniciando.
# 14908  497025804170444800  -Papi, cómo se hacen los niños? -Mira Jaimito,...
# 15021  497469850764472321  RT @ParejaCursis: Si fallaste ayer, no importa...
# 15037  497485848225775617  RT @FrassesDiarias: "Las mejores sonrisas son ...
# 15061  497595140031381504  RT @RealidadEnfrase: Sentirte estúpidamente fe...
#
#          split
# 17     future2
# 21     future2
# 58     future2
# 112    future2
# 125    future2
# ...        ...
# 14866  future2
# 14908  future2
# 15021  future2
# 15037  future2
# 15061  future2
#
# [472 rows x 3 columns]

# %%
df = humor_module.annotations_with_data.loc[humor_module.annotations_with_data.split == 'past']
columns = ['is_funny']
text_means = df.groupby('text_id').mean().loc[:, columns]
text_stds = df.groupby('text_id').std().loc[:, columns]

df = df.join(text_means, rsuffix='_mean', on='text_id').join(
    text_stds, rsuffix='_std', on='text_id')

for col in columns:
    df[col + '_z_score'] = (df[col] - df[col + '_mean']) / (df[col + '_std'] + 1e-8)

annotator_biases = df.groupby('annotator_id').mean(
).loc[:, [col + '_z_score' for col in columns]]

annotator_biases.columns = [col + '_bias' for col in columns]
annotator_biases.hist()
# Out:
# array([[<AxesSubplot:title={'center':'is_funny_bias'}>]], dtype=object)

# %%
import matplotlib.pyplot as plt
humor_module.annotations_with_data.annotator_id.value_counts().hist(bins=200)
plt.xlim(0, 100)
# Out:
# (0.0, 100.0)

# %% [markdown]
# ## Results analysis

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(18,12))
hparams_df = pd.read_csv('./data/hparams/hparams_search.csv')
hparams_df = hparams_df[hparams_df.words_per_text > 5]
hparams_df = hparams_df[hparams_df.embeddings_type.isin(['mpnet', 'xlmr'])]

sns.lineplot(data=hparams_df, x='min_word_count', y='test_loss', hue='model_type', style='dp_emb')
# Out:
# <AxesSubplot:xlabel='min_word_count', ylabel='test_loss'>

# %%
hparams_df[hparams_df.embeddings_type == 'mpnet'].groupby(['words_per_text', 'min_word_count', 'dp_emb', 'model_type'])['test_r2_is_funny'].mean()
# Out:
# words_per_text  min_word_count  dp_emb  model_type
# 10              5               0.00    bias              0.282560
#                                         embedding         0.293642
#                                         word_embedding    0.161087
#                                 0.25    bias              0.282266
#                                         embedding         0.284219
#                                         word_embedding    0.167597
#                 10              0.00    bias              0.312338
#                                         embedding         0.314500
#                                         word_embedding    0.162053
#                                 0.25    bias              0.289358
#                                         embedding         0.294060
#                                         word_embedding    0.151156
#                 50              0.00    bias              0.344809
#                                         embedding         0.341609
#                                         word_embedding    0.135063
#                                 0.25    bias              0.336292
#                                         embedding         0.330081
#                                         word_embedding    0.160692
# 15              5               0.00    bias              0.280316
#                                         embedding         0.287403
#                                         word_embedding    0.121395
#                                 0.25    bias              0.282926
#                                         embedding         0.285913
#                                         word_embedding    0.119251
#                 10              0.00    bias              0.301998
#                                         embedding         0.299602
#                                         word_embedding    0.116328
#                                 0.25    bias              0.284633
#                                         embedding         0.286424
#                                         word_embedding    0.096788
# Name: test_r2_is_funny, dtype: float64

# %% [markdown]
# ## Final results - no user folding

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(18,12))
hparams_df = pd.read_csv('./data/hparams/hparams_search.csv')
hparams_df
# Out:
#                         Name     State Notes    User  Tags  \
# 0          spooky-ghoul-1997   running     -  satyrr   NaN
# 1           spooky-cape-1996  finished     -  satyrr   NaN
# 2     terrifying-goblin-1995  finished     -  satyrr   NaN
# 3        strange-ritual-1994  finished     -  satyrr   NaN
# 4     trembling-phantom-1993  finished     -  satyrr   NaN
# ...                      ...       ...   ...     ...   ...
# 1992          dire-sorcery-5  finished     -  satyrr   NaN
# 1993        paranormal-cat-4  finished     -  satyrr   NaN
# 1994      ghostly-horseman-3  finished     -  satyrr   NaN
# 1995   supernatural-seance-2  finished     -  satyrr   NaN
# 1996         scary-wendigo-1  finished     -  satyrr   NaN
#
#                        Created  Runtime  Sweep          dataset  dp_emb  ...  \
# 0     2021-10-31T23:05:54.000Z       13    NaN  HumorDataModule    0.25  ...
# 1     2021-10-31T23:05:36.000Z       15    NaN  HumorDataModule    0.25  ...
# 2     2021-10-31T23:05:10.000Z       19    NaN  HumorDataModule    0.25  ...
# 3     2021-10-31T23:04:49.000Z       18    NaN  HumorDataModule    0.25  ...
# 4     2021-10-31T23:04:28.000Z       18    NaN  HumorDataModule    0.25  ...
# ...                        ...      ...    ...              ...     ...  ...
# 1992  2021-10-31T16:11:26.000Z        5    NaN  HumorDataModule    0.00  ...
# 1993  2021-10-31T16:11:19.000Z        5    NaN  HumorDataModule    0.00  ...
# 1994  2021-10-31T16:11:13.000Z        5    NaN  HumorDataModule    0.00  ...
# 1995  2021-10-31T16:11:06.000Z        5    NaN  HumorDataModule    0.00  ...
# 1996  2021-10-31T16:10:57.000Z        7    NaN  HumorDataModule    0.00  ...
#
#       epoch test_loss  test_r2_is_funny  test_r2_mean train_loss_epoch  \
# 0        13       NaN               NaN           NaN         0.076950
# 1        14  0.081616          0.255008      0.255008         0.073453
# 2        14  0.087828          0.184598      0.184598         0.091719
# 3        14  0.091393          0.149946      0.149946         0.095064
# 4        14  0.089098          0.171634      0.171634         0.093220
# ...     ...       ...               ...           ...              ...
# 1992     14  0.080579          0.278625      0.278625         0.056865
# 1993     14  0.079561          0.287823      0.287823         0.056160
# 1994     14  0.079448          0.288666      0.288666         0.055672
# 1995     14  0.079865          0.285194      0.285194         0.055827
# 1996     14  0.079747          0.286259      0.286259         0.056621
#
#       train_loss_step  trainer/global_step  valid_loss  valid_r2_is_funny  \
# 0            0.074207                  111    0.082701           0.242398
# 1            0.076139                  120    0.081730           0.251598
# 2            0.097149                  120    0.090940           0.175373
# 3            0.098314                  120    0.093914           0.147265
# 4            0.100448                  120    0.092317           0.161997
# ...               ...                  ...         ...                ...
# 1992         0.058181                  120    0.082477           0.265944
# 1993         0.056408                  120    0.081766           0.272242
# 1994         0.058739                  120    0.081456           0.274920
# 1995         0.059454                  120    0.082021           0.269933
# 1996         0.059071                  120    0.081960           0.270455
#
#       valid_r2_mean
# 0          0.242398
# 1          0.251598
# 2          0.175373
# 3          0.147265
# 4          0.161997
# ...             ...
# 1992       0.265944
# 1993       0.272242
# 1994       0.274920
# 1995       0.269933
# 1996       0.270455
#
# [1997 rows x 27 columns]

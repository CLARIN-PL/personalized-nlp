# %%
import pandas as pd

from pathlib import Path

# %%
data_dir = Path('..') / 'storage' / 'data' / 'jester'

data_path = data_dir / 'data_processed.csv'
annotations_path = data_dir / 'annotations_texts_folds.csv'

data_df = pd.read_csv(data_path)
annotations_df = pd.read_csv(annotations_path)

# %%
annotations_df
# Out:
#          annotator_id  text_id  humor  text_id_original  \
# 0                   0        0  -7.82                 1
# 1                   1        0   4.08                 1
# 2                   2        0   8.50                 1
# 3                   3        0  -6.17                 1
# 4                   4        0   6.84                 1
# ...               ...      ...    ...               ...
# 4136355         31958       99   3.98               100
# 4136356         48693       99   9.22               100
# 4136357         48903       99  -3.50               100
# 4136358         49099       99  -8.79               100
# 4136359         32022       99   5.44               100
#
#          annotator_id_original  fold
# 0                            0     3
# 1                            1     3
# 2                            4     3
# 3                            5     3
# 4                            7     3
# ...                        ...   ...
# ...
